# %%
import pandas as pd

# %%
df=pd.read_csv("studentinfo.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         77.0           90.0           71.0             90.0          2018.0
# 1         72.0           79.0            NaN             84.0          2018.0
# 2         80.0           81.0            NaN             92.0          2020.0
# 3         67.0           89.0            NaN             79.0          2019.0
# 4         75.0           81.0           66.0             89.0          2021.0
# ..         ...            ...            ...              ...             ...
# 84        65.0           87.0           65.0             88.0          2021.0
# 85        66.0           93.0           67.0             96.0          2019.0
# 86        68.0           89.0           80.0             81.0          2020.0
# 87        72.0           94.0           70.0             79.0          2018.0
# 88        73.0           88.0           75.0             75.0          2020.0
#
#     placement_offer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       85 non-null     float64
#  1   Reading_Score    84 non-null     float64
#  2   Writing_Score    86 non-null     float64
#  3   Placement_Score  81 non-null     float64
#  4   Club_Join_Date   83 non-null     float64
#  5   placement_offer  84 non-null     float64
# dtypes: float64(6)
# memory usage: 4.2 KB

# %%
df.isnull().sum()
# Out:
# Math_Score         4
# Reading_Score      5
# Writing_Score      3
# Placement_Score    8
# Club_Join_Date     6
# placement_offer    5
# dtype: int64

# %%
df.Math_Score.max()
# Out:
# np.float64(190.0)

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   85.000000      84.000000      86.000000        81.000000
# mean    68.964706      85.285714      69.837209        86.901235
# std     17.039483       7.230410       6.392754         8.183222
# min    -10.000000      49.000000      60.000000        60.000000
# 25%     63.000000      80.500000      64.250000        81.000000
# 50%     67.000000      86.000000      69.000000        86.000000
# 75%     73.000000      91.000000      75.000000        94.000000
# max    190.000000      95.000000      80.000000       100.000000
#
#        Club_Join_Date  placement_offer
# count       83.000000        84.000000
# mean      2019.530120         2.392857
# std          1.140575         0.676950
# min       2018.000000         1.000000
# 25%       2018.500000         2.000000
# 50%       2020.000000         2.500000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
x=df.Math_Score.mean()

# %%
df.Math_Score.fillna(x)
# Out:
# 0     77.0
# 1     72.0
# 2     80.0
# 3     67.0
# 4     75.0
#       ...
# 84    65.0
# 85    66.0
# 86    68.0
# 87    72.0
# 88    73.0
# Name: Math_Score, Length: 89, dtype: float64

# %%
df.Math_Score.fillna(x,inplace=True)
# Out:
# <ipython-input-14-975b01b29bfb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_Score.fillna(x,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         77.0           90.0           71.0             90.0          2018.0
# 1         72.0           79.0            NaN             84.0          2018.0
# 2         80.0           81.0            NaN             92.0          2020.0
# 3         67.0           89.0            NaN             79.0          2019.0
# 4         75.0           81.0           66.0             89.0          2021.0
# ..         ...            ...            ...              ...             ...
# 84        65.0           87.0           65.0             88.0          2021.0
# 85        66.0           93.0           67.0             96.0          2019.0
# 86        68.0           89.0           80.0             81.0          2020.0
# 87        72.0           94.0           70.0             79.0          2018.0
# 88        73.0           88.0           75.0             75.0          2020.0
#
#     placement_offer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     float64
#  1   Reading_Score    84 non-null     float64
#  2   Writing_Score    86 non-null     float64
#  3   Placement_Score  81 non-null     float64
#  4   Club_Join_Date   83 non-null     float64
#  5   placement_offer  84 non-null     float64
# dtypes: float64(6)
# memory usage: 4.2 KB

# %%
df.iloc[1:4,2:3].fillna(69,inplace=True)
# Out:
# <ipython-input-23-709077ea065f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.iloc[1:4,2:3].fillna(69,inplace=True)

# %%
df.Placement_Score.fillna(222,inplace=True)
# Out:
# <ipython-input-24-1162ce8df9ef>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Score.fillna(222,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         77.0           90.0           71.0             90.0          2018.0
# 1         72.0           79.0           69.0             84.0          2018.0
# 2         80.0           81.0           69.0             92.0          2020.0
# 3         67.0           89.0           69.0             79.0          2019.0
# 4         75.0           81.0           66.0             89.0          2021.0
# ..         ...            ...            ...              ...             ...
# 84        65.0           87.0           65.0             88.0          2021.0
# 85        66.0           93.0           67.0             96.0          2019.0
# 86        68.0           89.0           80.0             81.0          2020.0
# 87        72.0           94.0           70.0             79.0          2018.0
# 88        73.0           88.0           75.0             75.0          2020.0
#
#     placement_offer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     float64
#  1   Reading_Score    84 non-null     float64
#  2   Writing_Score    89 non-null     float64
#  3   Placement_Score  89 non-null     float64
#  4   Club_Join_Date   83 non-null     float64
#  5   placement_offer  84 non-null     float64
# dtypes: float64(6)
# memory usage: 4.2 KB

# %%
df.Reading_Score.fillna(85,inplace=True)
# Out:
# <ipython-input-27-3a6f40a0f619>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_Score.fillna(85,inplace=True)

# %%
df.Club_Join_Date.mode()
# Out:
# 0    2021.0
# Name: Club_Join_Date, dtype: float64

# %%
df.Club_Join_Date.fillna(2021,inplace=True)
# Out:
# <ipython-input-29-d2d3c7046829>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Club_Join_Date.fillna(2021,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     float64
#  1   Reading_Score    89 non-null     float64
#  2   Writing_Score    89 non-null     float64
#  3   Placement_Score  89 non-null     float64
#  4   Club_Join_Date   89 non-null     float64
#  5   placement_offer  84 non-null     float64
# dtypes: float64(6)
# memory usage: 4.2 KB

# %%
df.placement_offer.fillna(2,inplace=True)
# Out:
# <ipython-input-31-01299fb3d259>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.placement_offer.fillna(2,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     float64
#  1   Reading_Score    89 non-null     float64
#  2   Writing_Score    89 non-null     float64
#  3   Placement_Score  89 non-null     float64
#  4   Club_Join_Date   89 non-null     float64
#  5   placement_offer  89 non-null     float64
# dtypes: float64(6)
# memory usage: 4.2 KB

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', 'placement_offer'],
#       dtype='object')

# %%
df.placement_offer.fillna(10,inplace=True)
# Out:
# <ipython-input-34-a48944aa9f82>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.placement_offer.fillna(10,inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', 'placement_offer'],
#       dtype='object')

# %%
col=['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
       'Club_Join_Date', 'placement_offer']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.scatterplot(Placement_Score,placement_offer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.scatterplot(Placement_Score,placement_offer)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['Placement_Score'],df['placement_offer'])

# %%
plt.show()

# %%
import numpy as np

# %%
q1=np.percentile(df.placement_offer,25)

# %%
q1
# Out:
# np.float64(2.0)

# %%
df.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# count   89.000000      89.000000      89.000000        89.000000
# mean    68.964706      85.269663      69.808989        99.044944
# std     16.647718       7.022309       6.284679        39.635530
# min    -10.000000      49.000000      60.000000        60.000000
# 25%     64.000000      81.000000      65.000000        81.000000
# 50%     68.000000      86.000000      69.000000        87.000000
# 75%     73.000000      90.000000      75.000000        97.000000
# max    190.000000      95.000000      80.000000       222.000000
#
#        Club_Join_Date  placement_offer
# count       89.000000        89.000000
# mean      2019.629213         2.370787
# std          1.161719         0.663702
# min       2018.000000         1.000000
# 25%       2019.000000         2.000000
# 50%       2020.000000         2.000000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
q3=np.percentile(df.placement_offer,75)

# %%
IQR=q3-q1

# %%
IQR
# Out:
# np.float64(1.0)

# %%
upper_bod=q3+1.5*IQR

# %%
upper_bod
# Out:
# np.float64(4.5)

# %%
lower_bod=q1-1.5*IQR

# %%
lower_bod
# Out:
# np.float64(0.5)

# %%
from scipy import stats

# %%
z=np.abs(stats.zscore(df['placement_offer'])
# Out:
#   Cell In[62], line 1
#     z=np.abs(stats.zscore(df['placement_offer'])
#                                                 ^
# _IncompleteInputError: incomplete input
