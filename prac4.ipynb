# %%
Priyanka Jadhav

# %%
a=101
b="hello"
c=True
d=45.6

# %%
print(a)
# Out:
# 101

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
id(a)
# Out:
# 3873852

# %%
id(b)
# Out:
# 70050880

# %%
x = 50  
x = 60.5  
x = "Hello World"  
#x = ["geeks", "for", "geeks"] 
x = ("geeks", "for", "geeks")

# %%
print(x)
# Out:
# ['geeks', 'for', 'geeks']

# %%
type(x)
# Out:
# list

# %%
print(x)
# Out:
# ('geeks', 'for', 'geeks')

# %%
type(x)
# Out:
# tuple

# %%
name='priya'
name2="priya"
name3=""" priya"""
print(name,name2,name3)
# Out:
# priya priya  priya

# %%
a="pythonProgramming"

# %%
a[6]
# Out:
# 'P'

# %%
a[6:]
# Out:
# 'Programming'

# %%
a[0:6]
# Out:
# 'python'

# %%
a[0:-11]
# Out:
# 'python'

# %%
a[:6]
# Out:
# 'python'

# %%
a[:-11]
# Out:
# 'python'

# %%
a[:-1]+"e"
# Out:
# 'pythonProgrammine'

# %%
a[:6]+"prog"
# Out:
# 'pythonprog'

# %%
b=[11,2,3,4,5]

# %%
b
# Out:
# [11, 2, 3, 4, 5]

# %%
b=[45,56,'STR']

# %%
b[2]
# Out:
# 'STR'

# %%
type(b)
# Out:
# list

# %%
a=[[1,2,3,4],["piya","riya","siya"],[2,3,4]]

# %%
a[2][2]
# Out:
# 4

# %%
a[1][1]
# Out:
# 'riya'

# %%
a[0][:]
# Out:
# [1, 2, 3, 4]

# %%
a[:][0]
# Out:
# [1, 2, 3, 4]

# %%
a=[1,'piya',[1,2,'siya']]

# %%
a[2][2]
# Out:
# 'siya'

# %%
a[2][2][3:]
# Out:
# 'a'

# %%
a[1]="raj"

# %%
a[1]
# Out:
# 'raj'

# %%
a.remove("raj")

# %%
a
# Out:
# [1, [1, 2, 'siya']]

# %%
a.clear()

# %%
a
# Out:
# []

# %%
a.append("priya")

# %%
a
# Out:
# ['priya']

# %%
a.append(4545)

# %%
a[1]
# Out:
# 4545

# %%
a.extend(["gaurav",26])

# %%
a.extend(["aman",23])

# %%
a
# Out:
# ['priya', 4545, 'gaurav', 26, 'aman', 23]

# %%
a.remove(['gaurav', 26])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 a.remove(['gaurav', 26])
#
# ValueError: list.remove(x): x not in list

# %%
a
# Out:
# ['priya', 4545, 'gaurav', 26, 'aman', 23]

# %%
b=('priya','riya','siya')

# %%
b
# Out:
# ('priya', 'riya', 'siya')

# %%
a=list(b)

# %%
a
# Out:
# ['priya', 'riya', 'siya']

# %%
a.append("raj")

# %%
a=('priya',45,True)

# %%
a
# Out:
# ('priya', 45, True)

# %%
d1={1:"priya",2:"aman",3:"riya"}

# %%
d1
# Out:
# {1: 'priya', 2: 'aman', 3: 'riya'}

# %%
d2=[{'name':'priya',
     'roll':34}
    ,
    {'name':'aman',
     'roll': 35}]

# %%
d2
# Out:
# [{'name': 'priya', 'roll': 34}, {'name': 'aman', 'roll': 35}]

# %%
d2[1]['name']
# Out:
# 'aman'

# %%
del d2[0]['roll']

# %%
d2
# Out:
# [{'name': 'priya'}, {'name': 'aman', 'roll': 35}]

# %%
d2[0]['rollno']=34

# %%
d2
# Out:
# [{'name': 'priya', 'rollno': 34}, {'name': 'aman', 'roll': 35}]

# %%
names = [student['name'] for student in d2]
print(names)
# Out:
# ['priya', 'aman']

# %%
a=[1,2,3,4,5]
b=set(a)
b
# Out:
# {1, 2, 3, 4, 5}

# %%
a=[45,3,4,2,3,2,1,]
b=set(a)
b
# Out:
# {1, 2, 3, 4, 45}

# %%
a=["python", 'java','c++']
ab=set(a)
ab
# Out:
# {'c++', 'java', 'python'}

# %%
a=10+20
a
# Out:
# 30

# %%
b=34-56
b
# Out:
# -22

# %%
b==a
# Out:
# False

# %%
c+=45
c
# Out:
# 91

# %%
d-=67
d
# Out:
# -21.4

# %%
f=45/56
f
# Out:
# 0.8035714285714286

# %%
name= input("Enter the name :")
name
# Out:
# Enter the name : priya
# 'priya'

# %%
rollno =int(input("ENter the Rollno: "))
rollno
# Out:
# ENter the Rollno:  13210
# 13210

# %%
print("name :",name,"Rollno :",rollno)
# Out:
# name : priya Rollno : 13210

# %%
age=int(input("ENter the age :"))
if(age>=18):
  print("your are eligibal for vote")
else:
  print("yue are not eligibal for vote")
# Out:
# ENter the age : 21
# your are eligibal for vote

# %%
mark=int(input("Enter your marks:"))
if(mark>=85):
  print("A Grade")
elif(mark>=75):
  print("B Grade")
elif(mark>=65):
  print("C Grade")
else:
  print("RIP")
# Out:
# Enter your marks: 90
# A Grade

# %%
n=int(input("Enter the number :"))
for i in range(1,11):
  print(n*i)
# Out:
# Enter the number : 6
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %%
def greet(x,y):
  print(f" {x} hi how are you how i can help you {y}  ")

# %%
def greet():
  print("without paramater  ")

# %%
name=input("Enter your name :")
# Out:
# Enter your name : priya

# %%
greet()
# Out:
# without paramater

# %%
def greet(x,y):
  print(f" {x} hi how are you how i can help you {y}  ")

# %%
greet(x='priya',y=12)
# Out:
#  priya hi how are you how i can help you 12

# %%
def greet(x):
  print(f"Hi {x}")

# %%
greet("Priya")
# Out:
# Hi Priya
