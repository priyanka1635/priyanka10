# %% [markdown]
# Practical No:07
#
# Priyanka Jadhav
#
# Rollno:13210(B1)

# %%
import nltk

# Force correct path
nltk.data.path.append("C:\\Users\\priya\\AppData\\Roaming\\nltk_data")

# Re-download properly
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
print(nltk.data.find('tokenizers/punkt'))
# Out:
# /root/nltk_data/tokenizers/punkt

# %%
#Sentence Tokenization
from nltk.tokenize import sent_tokenize

text = """Tokenization is the first step in text analytics. The
process of breaking down a text paragraph into smaller
chunks such as words or sentences is called Tokenization."""

tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Tokenization is the first step in text analytics.', 'The\nprocess of breaking down a text paragraph into smaller\nchunks such as words or sentences is called Tokenization.']

# %%
#Word Tokenization
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
import nltk
# print stop words of English
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'now', 'a', "it'll", 'between', 'in', 'o', 'other', 'when', 'any', 'up', "won't", 'haven', 'do', 'will', 'ain', 'further', 'wouldn', 'doing', 't', 'as', 'on', 'same', 'theirs', 'himself', 'can', "he's", 'ourselves', 'what', 'hers', 'aren', 'hasn', 'until', "you've", 'did', 'his', 'needn', "they're", 'by', 'weren', 'yourself', 'm', "should've", 'at', "it's", 'itself', 'of', 'own', 'after', 'again', 'against', 'over', 'above', 'who', 'll', 'under', 'you', 'once', "i'd", "they'll", "isn't", "we've", "hadn't", 'him', 's', 'it', 'wasn', "you'd", 'to', 'these', "you'll", 'during', 'only', 'than', 'doesn', 'me', 'being', 'both', "aren't", 'her', "wouldn't", 'for', 'they', 'down', 'few', 'be', 'mightn', 'themselves', 'myself', "that'll", 'don', "you're", 'your', 'didn', 'that', 'if', "haven't", "she'll", 'herself', 'some', 'but', 'my', 'before', 'here', "i'll", 'is', 'were', 'our', 'where', 'we', 'yourselves', 'which', "i'm", 'its', 'mustn', 'he', 'so', 'through', 'such', "hasn't", "it'd", 'with', "don't", 'into', 'whom', 'how', 'from', 'been', "he'd", "shan't", 've', 'she', 'or', "mustn't", 'am', 'are', "she'd", "he'll", 'no', 'all', 'nor', 'why', "we'd", "they'd", "weren't", 'having', "needn't", 'most', 're', 'then', 'yours', 'an', "they've", 'have', 'their', "we'll", 'there', "shouldn't", 'each', 'off', 'very', "wasn't", 'because', "couldn't", 'had', 'hadn', 'shouldn', 'does', "doesn't", 'those', 'shan', "mightn't", 'ours', 'couldn', 'about', 'isn', 'more', 'the', 'them', 'was', 'too', "i've", 'and', 'below', 'while', 'won', 'y', 'this', "she's", "didn't", 'ma', 'just', 'should', 'out', 'has', "we're", 'd', 'i', 'not'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.corpus import stopwords

# %%
stop_word=set(stopwords.words("english"))

# %%
import re

# %%
clean_text=re.sub('[^a-zA-Z]',' ',text)
tokens = word_tokenize(clean_text.lower())

# %%
filtered_words =[w for w in tokens if w not in stop_words]
print("\nFiltered Words:\n", filtered_words)
# Out:
# Filtered Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed_words =[ps.stem(w)for w in filtered_words]
print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['token', 'first', 'step', 'text', 'analyt', 'process', 'break', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentenc', 'call', 'token']

# %%
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_words =[lemmatizer.lemmatize(w)for w in filtered_words]
print("\nLemmatized Words:\n", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Lemmatized Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentence', 'called', 'tokenization']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
pos_tags = nltk.pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('tokenization', 'NN'), ('first', 'RB'), ('step', 'VB'), ('text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('breaking', 'VBG'), ('text', 'NN'), ('paragraph', 'NN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('words', 'NNS'), ('sentences', 'NNS'), ('called', 'VBD'), ('tokenization', 'NN')]

# %%
pos_tags = nltk.pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('tokenization', 'NN'), ('first', 'RB'), ('step', 'VB'), ('text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('breaking', 'VBG'), ('text', 'NN'), ('paragraph', 'NN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('words', 'NNS'), ('sentences', 'NNS'), ('called', 'VBD'), ('tokenization', 'NN')]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documentA ='Jupiter is the largest Planet'
documentB ='Mars is the fourth planet from the Sun'

# %%
documents =[documentA, documentB]
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(clean_text.lower())
clean_text = re.sub('[^a-zA-Z]',' ', text)

# %%
filtered_words =[w for w in tokens if w not in stop_words]
print("\nFiltered Words:\n", filtered_words)
# Out:
# Filtered Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed_words =[ps.stem(w)for w in filtered_words]
print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['token', 'first', 'step', 'text', 'analyt', 'process', 'break', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentenc', 'call', 'token']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_words =[lemmatizer.lemmatize(w)for w in filtered_words]
print("\nLemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentence', 'called', 'tokenization']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = nltk.pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('tokenization', 'NN'), ('first', 'RB'), ('step', 'VB'), ('text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('breaking', 'VBG'), ('text', 'NN'), ('paragraph', 'NN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('words', 'NNS'), ('sentences', 'NNS'), ('called', 'VBD'), ('tokenization', 'NN')]

# %%
processed_docs = []

for doc in documents:
    doc = doc.lower()
    words = word_tokenize(doc)
    filtered_words = [w for w in words if w not in stop_words]
    processed_docs.append(filtered_words)

print("Processed Documents:")

for i, doc in enumerate(processed_docs):
    print(f"Doc {i+1}: {doc}")
# Out:
# Processed Documents:
# Doc 1: ['jupiter', 'largest', 'planet']
# Doc 2: ['mars', 'fourth', 'planet', 'sun']

# %%
vocab = set()
for doc in processed_docs:
    vocab.update(doc)
vocab = list(vocab)
print("\nVocabulary:", vocab)
# Out:
# Vocabulary: ['planet', 'sun', 'jupiter', 'fourth', 'largest', 'mars']

# %%
def compute_tf(doc):
    tf_dict ={}
    doc_len = len(doc)
    print("\nTF Calculation:")
    for word in vocab:
        count = doc.count(word)
        tf = count / doc_len
        tf_dict[word]= tf
        print(f"{word} = {count}/{doc_len} = {tf}")
        return tf_dict
tf_docs =[]
for i, doc in enumerate(processed_docs):
    print(f"\n--- TF for Document {i+1} ---")
    tf_docs.append(compute_tf(doc))
# Out:
# --- TF for Document 1 ---
#
# TF Calculation:
# planet = 1/3 = 0.3333333333333333
#
# --- TF for Document 2 ---
#
# TF Calculation:
# planet = 1/4 = 0.25

# %%
from collections import Counter

# Step 1: Define document
docA = "Tokenization is the first step in text analytics"

# Step 2: Split into words
bagOfWordsA = docA.split()

# Step 3: Count frequency
wordDictA = Counter(bagOfWordsA)

# Step 4: Count total words
numOfWordsA = len(bagOfWordsA)

# Output
print("Bag of Words:", bagOfWordsA)
print("Word Frequency:", wordDictA)
print("Total Words:", numOfWordsA)
# Out:
# Bag of Words: ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics']
# Word Frequency: Counter({'Tokenization': 1, 'is': 1, 'the': 1, 'first': 1, 'step': 1, 'in': 1, 'text': 1, 'analytics': 1})
# Total Words: 8

# %%
def computeTF(wordDict, totalWords):
    tfDict = {}

    print("Word Counts:", wordDict)
    print("\nTF Values:\n")

    for word, count in wordDict.items():
        tf = count / float(totalWords)
        tfDict[word] = tf

    return tfDict

# %%
tfA = computeTF(wordDictA, numOfWordsA)
# Out:
# Word Counts: Counter({'Tokenization': 1, 'is': 1, 'the': 1, 'first': 1, 'step': 1, 'in': 1, 'text': 1, 'analytics': 1})
#
# TF Values:

# %%
import math

def compute_idf(docs):
    N = len(docs)
    idf_dict = {}

    print("\nIDF Calculation:")

    # Create vocabulary (unique words)
    vocab = set(word for doc in docs for word in doc)

    for word in vocab:
        count = sum(1 for doc in docs if word in doc)
        idf = math.log(N / (count + 1)) + 1   # smoothing
        idf_dict[word] = idf

        print(f"{word} → appears in {count} docs → IDF = {idf}")

    return idf_dict


# Call function
idf = compute_idf(processed_docs)
# Out:
# IDF Calculation:
# planet → appears in 2 docs → IDF = 0.5945348918918356
# sun → appears in 1 docs → IDF = 1.0
# jupiter → appears in 1 docs → IDF = 1.0
# fourth → appears in 1 docs → IDF = 1.0
# largest → appears in 1 docs → IDF = 1.0
# mars → appears in 1 docs → IDF = 1.0

# %%
def compute_tfidf(tf, idf):
    tfidf = {}

    for word in tf:   # use words from tf instead of global vocab
        tfidf[word] = tf[word] * idf[word]

    return tfidf


tfidf_docs = []

for i, tf in enumerate(tf_docs):
    tfidf_docs.append(compute_tfidf(tf, idf))

print("\nTF-IDF Results:")

for i, tfidf in enumerate(tfidf_docs):
    print(f"\nDocument {i+1}:")

    for word, value in tfidf.items():
        print(f"{word}: {value}")
# Out:
# TF-IDF Results:
#
# Document 1:
# planet: 0.19817829729727854
#
# Document 2:
# planet: 0.1486337229729589
