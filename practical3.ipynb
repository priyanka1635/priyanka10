# %%
import pandas as pd

# %%
df=pd.read_csv("studentinfo.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           77           90.0             71             90.0            2018
# 1           72           79.0             70             84.0            2018
# 2           80           81.0             71             92.0            2020
# 3           67           89.0             74             79.0            2019
# 4           75           81.0             66             89.0            2021
# ..         ...            ...            ...              ...             ...
# 84          65           87.0             65             88.0            2021
# 85          66           93.0             67             96.0            2019
# 86          68           89.0             80             81.0            2020
# 87          72           94.0             70             79.0            2018
# 88          73           88.0             75             75.0            2020
#
#     placement_offer
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           77           90.0             71             90.0            2018
# 1           72           79.0             70             84.0            2018
# 2           80           81.0             71             92.0            2020
# 3           67           89.0             74             79.0            2019
# 4           75           81.0             66             89.0            2021
# ..         ...            ...            ...              ...             ...
# 84          65           87.0             65             88.0            2021
# 85          66           93.0             67             96.0            2019
# 86          68           89.0             80             81.0            2020
# 87          72           94.0             70             79.0            2018
# 88          73           88.0             75             75.0            2020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       89 non-null     int64
#  1   Reading_Score    84 non-null     float64
#  2   Writing_Score    89 non-null     int64
#  3   Placement_Score  81 non-null     float64
#  4   Club_Join_Date   89 non-null     int64
#  5   placement_offer  89 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 4.2 KB

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# ..         ...            ...            ...              ...             ...
# 84       False          False          False            False           False
# 85       False          False          False            False           False
# 86       False          False          False            False           False
# 87       False          False          False            False           False
# 88       False          False          False            False           False
#
#     placement_offer
# ...

# %%
series=pd.isnull(df["Reading_Score"])

# %%
df[series]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 19          65            NaN             80             95.0            2021
# 20          78            NaN             67             99.0            2018
# 21          70            NaN             68             75.0            2019
# 22          67            NaN             70             91.0            2021
# 23          76            NaN             78             96.0            2018
#
#     placement_offer
# 19                3
# 20                3
# 21                2
# 22                3
# 23                3

# %%
df.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# ..         ...            ...            ...              ...             ...
# 84        True           True           True             True            True
# 85        True           True           True             True            True
# 86        True           True           True             True            True
# 87        True           True           True             True            True
# 88        True           True           True             True            True
#
#     placement_offer
# ...

# %%
series1=pd.notnull(df["Reading_Score"])

# %%
df[series1]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           77           90.0             71             90.0            2018
# 1           72           79.0             70             84.0            2018
# 2           80           81.0             71             92.0            2020
# 3           67           89.0             74             79.0            2019
# 4           75           81.0             66             89.0            2021
# ..         ...            ...            ...              ...             ...
# 84          65           87.0             65             88.0            2021
# 85          66           93.0             67             96.0            2019
# 86          68           89.0             80             81.0            2020
# 87          72           94.0             70             79.0            2018
# 88          73           88.0             75             75.0            2020
#
#     placement_offer
# ...

# %%
ndf=df

# %%
y=ndf.fillna(0,inplace=True)

# %%
series=pd.isnull(ndf["Reading_Score"])

# %%
ndf[series]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 19          65            NaN             80             95.0            2021
# 20          78            NaN             67             99.0            2018
# 21          70            NaN             68             75.0            2019
# 22          67            NaN             70             91.0            2021
# 23          76            NaN             78             96.0            2018
#
#     placement_offer
# 19                3
# 20                3
# 21                2
# 22                3
# 23                3

# %%
missing_values = ["Na", "na"]

# %%
df = pd.read_csv("studentinfo.csv", na_values=missing_values)

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           77           90.0             71             90.0            2018
# 1           72           79.0             70             84.0            2018
# 2           80           81.0             71             92.0            2020
# 3           67           89.0             74             79.0            2019
# 4           75           81.0             66             89.0            2021
# ..         ...            ...            ...              ...             ...
# 84          65           87.0             65             88.0            2021
# 85          66           93.0             67             96.0            2019
# 86          68           89.0             80             81.0            2020
# 87          72           94.0             70             79.0            2018
# 88          73           88.0             75             75.0            2020
#
#     placement_offer
# ...
